# %% [markdown]
# <a href="https://colab.research.google.com/github/nbilasals/segmentasi_jentik_nyamuk/blob/main/segmentasi_jentik_otsu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CONNECT GOOGLE DRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import Library
import cv2
import imutils
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
import cv2
from matplotlib import pyplot as plt

def detect_mosquito_larvae(image_path):
    # Baca Gambar
    image = cv2.imread(image_path)

    # Ubah citra ke grascale
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Menentukan Otsu Treshold
    otsu_threshold, image_otsu = cv2.threshold(
        image_gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU
    )

    # Denoising Otsu
    image_otsu_clean = cv2.fastNlMeansDenoising(image_otsu, None, 20, 7, 21)

    # Gaussian Blur
    blur = cv2.GaussianBlur(image_otsu_clean, (11, 11), 0)

    # Deteksi Tepi - Canny
    canny = cv2.Canny(blur, 30, 150, 3)

    # Dilasi
    dilated = cv2.dilate(canny, (1, 1), iterations=1)

    # Count Jentik
    (cnt, hierarchy) = cv2.findContours(
      dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    rgb = cv2.cvtColor(image_otsu, cv2.COLOR_BGR2RGB)
    cv2.drawContours(rgb, cnt, -1, (0, 255, 0), 2)

    # Tampilkan semua langkah dalam prosesnya
    plt.figure(figsize=(15, 10))
    plt.subplot(2, 4, 1), plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)), plt.title('Original Image')
    plt.subplot(2, 4, 2), plt.imshow(image_gray, cmap='gray'), plt.title('Grayscale Image')
    plt.subplot(2, 4, 3), plt.imshow(image_otsu, cmap='gray'), plt.title(f'Otsu Threshold (Threshold={otsu_threshold})')
    plt.subplot(2, 4, 4), plt.imshow(image_otsu_clean, cmap='gray'), plt.title('Denoising Otsu')
    plt.subplot(2, 4, 5), plt.imshow(blur, cmap='gray'), plt.title('Gaussian Blur')
    plt.subplot(2, 4, 6), plt.imshow(canny, cmap='gray'), plt.title('Canny Edge Detection')
    plt.subplot(2, 4, 7), plt.imshow(dilated, cmap='gray'), plt.title('Dilated Image')
    plt.subplot(2, 4, 8), plt.imshow(rgb), plt.title(f'Found({len(cnt)} Mosquito Larvae)')

    return len(cnt)

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/jentik1.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  7

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/rem1.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  10

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/rem2.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  5

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/rem3.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  22

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/jentik2.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  9

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/jentik3.jpeg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  26

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/IMG_20231009_204317.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  41

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/IMG_20231008_215808.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  9

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/IMG_20231009_203917.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  16

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/IMG_20231009_204041.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  13

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/IMG_20231009_204131.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  13

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/IMG_20231009_204236.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  10

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/IMG_20231009_204302.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  6

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/IMG_20231009_204342.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  38

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/IMG_20231009_204413.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  34

# %%
image_path = "/content/drive/MyDrive/dataset/otsu/data/IMG_20231009_204445.jpg"
jumlah_jentik = detect_mosquito_larvae(image_path)
print("Jumlah Jentik Nyamuk: ", jumlah_jentik)
# Out:
# Jumlah Jentik Nyamuk:  10

# %% [markdown]
# ## Count Jentik Nyamuk

# %%
# Baca Gambar
image = cv2.imread("/content/drive/MyDrive/dataset/otsu/data/rem3.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1022x1042>

# %%
# Ubah citra ke grascale
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(image_gray)
# Out:
# <PIL.Image.Image image mode=L size=1022x1042>

# %%
#Menyimpan Grayscale
savePath = "/content/drive/MyDrive/dataset/otsu/result/jentik2_gray.jpg"
cv2.imwrite(savePath, image_gray)

# %%
# Menentukan Otsu Treshold
otsu_threshold, image_otsu = cv2.threshold(
    image_gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU,
)
print("Obtained threshold: ", otsu_threshold)
# Out:
# Obtained threshold:  199.0

# %%
# Plot Hasil Gambar Otsu
from google.colab.patches import cv2_imshow
cv2_imshow(image_otsu)
# Out:
# <PIL.Image.Image image mode=L size=1022x1042>

# %%
#Menyimpan Otsu
savePath = "/content/drive/MyDrive/dataset/otsu/result/jentik2_otsu.jpg"
cv2.imwrite(savePath, image_otsu)

# %%
#Denosing Otsu
image_otsu_clean = cv2.fastNlMeansDenoising(image_otsu, None, 20, 7, 21)
cv2_imshow(image_otsu_clean)
# Out:
# <PIL.Image.Image image mode=L size=1022x1042>

# %%
#Menyimpan Denoise
savePath = "/content/drive/MyDrive/dataset/otsu/result/jentik4_denoise.jpg"
cv2.imwrite(savePath, image_otsu_clean)

# %%
#Gaussian Blur
blur = cv2.GaussianBlur(image_otsu_clean, (11, 11), 0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=1022x1042>

# %%
#Menyimpan GaussianBlur
savePath = "/content/drive/MyDrive/dataset/otsu/result/jentik4_gaussianblur.jpg"
cv2.imwrite(savePath, blur)

# %%
#Deteksi Tepi - Canny
canny = cv2.Canny(blur, 30, 150, 3)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=1022x1042>

# %%
#Menyimpan Canny
savePath = "/content/drive/MyDrive/dataset/otsu/result/jentik4_canny.jpg"
cv2.imwrite(savePath, canny)

# %%
#Dilasi
dilated = cv2.dilate(canny, (1, 1), iterations=0)
cv2_imshow(dilated)
# Out:
# <PIL.Image.Image image mode=L size=1022x1042>

# %%
#Menyimpan Dilasi
savePath = "/content/drive/MyDrive/dataset/otsu/result/jentik4_dilasi.jpg"
cv2.imwrite(savePath, dilated)
# Out:
# True

# %%
#Count Jentik
(cnt, hierarchy) = cv2.findContours(
    dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
rgb = cv2.cvtColor(image_otsu, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb, cnt, -1, (0, 255, 0), 2)

cv2_imshow(rgb)
print("Jentik Pada Gambar : ", len(cnt))
# Out:
# <PIL.Image.Image image mode=RGB size=1022x1042>
# Jentik Pada Gambar :  35

# %%
#Menyimpan Count
savePath = "/content/drive/MyDrive/dataset/otsu/result/jentik4_count.jpg"
cv2.imwrite(savePath, rgb)

# %%
import numpy as np

# Masukkan data jumlah jentik nyamuk manual dan program ke dalam array
jumlah_manual = np.array([6, 5, 5, 16])  # Data jumlah jentik nyamuk hasil perhitungan manual
jumlah_program = np.array([7, 13, 5, 35])  # Data jumlah jentik nyamuk hasil perhitungan program

# Menghitung Mean Square Error (MSE) untuk setiap data
mse = (jumlah_manual - jumlah_program) ** 2

# Menghitung Root Mean Square Error (RMSE) untuk setiap data
rmse = np.sqrt(mse)

# Menampilkan hasil MSE dan RMSE untuk setiap data
for i in range(len(jumlah_manual)):
    print(f"Data ke-{i+1}:")
    print(f"MSE: {mse[i]}")
    print(f"RMSE: {rmse[i]}")
    print()

# Menghitung rata-rata MSE dan RMSE
mse_avg = np.mean(mse)
rmse_avg = np.mean(rmse)

# Menampilkan hasil rata-rata MSE dan RMSE
print(f"Rata-rata MSE: {mse_avg}")
print(f"Rata-rata RMSE: {rmse_avg}")
# Out:
# Data ke-1:
# MSE: 1
# RMSE: 1.0
#
# Data ke-2:
# MSE: 64
# RMSE: 8.0
#
# Data ke-3:
# MSE: 0
# RMSE: 0.0
#
# Data ke-4:
# MSE: 361
# RMSE: 19.0
#
# Rata-rata MSE: 106.5
# Rata-rata RMSE: 7.0
